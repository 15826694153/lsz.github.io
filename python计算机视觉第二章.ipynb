# %%
from PIL import Image
from numpy import *
from pylab import *
import harris
im = array(Image.open('empire.jpg').convert('L'))
harrisim = harris.compute_harris_response(im)
filtered_coords = harris.get_harris_points(harrisim,6)
harris.plot_harris_points(im, filtered_coords)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-261e3d169953> in <module>()
#       4 import harris
#       5 im = array(Image.open('empire.jpg').convert('L'))
# ----> 6 harrisim = harris.compute_harris_response(im)
#       7 filtered_coords = harris.get_harris_points(harrisim,6)
#       8 harris.plot_harris_points(im, filtered_coords)
#
# /media/qiu/新加卷2/python/harris.py in compute_harris_response(im, sigma)
#       6
#       7         # 计算导数
# ----> 8         imx = zeros(im.shape)
#       9         filters.gaussian_filter(im, (sigma,sigma), (0,1), imx)
#      10         imy = zeros(im.shape)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'x'

# %%
from PIL import Image
from numpy import *
from pylab import *
import sift
imname = 'empire.jpg'
im1 = array(Image.open(imname).convert('L'))
sift.process_image(imname,'empire.sift')
l1,d1 = sift.read_features_from_file('empire.sift')
figure()
gray()
sift.plot_features(im1,l1,circle=True)
show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-61a48a9029a6> in <module>()
#       2 from numpy import *
#       3 from pylab import *
# ----> 4 import sift
#       5 imname = 'empire.jpg'
#       6 im1 = array(Image.open(imname).convert('L'))
#
# ModuleNotFoundError: No module named 'sift'

# %%
from scipy import ndimage
im = array(Image.open('empire.jpg').convert('L'))
H = array([[1.4,0.05,-100],[0.05,1.5,-100],[0,0,1]])
im2 = ndimage.affine_transform(im,H[:2,:2],(H[0,2],H[1,2]))
figure()
gray()
imshow(im2)
axis('off')  #不显示坐标轴
# Out:
# (-0.5, 1023.5, 639.5, -0.5)
